# %% [markdown]
# # Notebook SAE trans ROBERT Bastien LEDRU Colin

# %%
#Import des librairies

import matplotlib.pyplot as plt
import sounddevice as sd
from scipy.fftpack import fft
import numpy as np

# %% [markdown]
# # Programme affichage de la sinusoïdale

# %%
fs = 100000 #Échantillonnage
d = 5 #Temps de réception

print("Start recording")

a = sd.rec(int(d * fs), samplerate=fs, channels=1) #Réception du signal (fréquence de 1000)
sd.wait()

print("End recording")

plt.figure(figsize=(12,6)) #Taille de la figure

ax = plt.axes()
plt.xlim(80000,80300)

ax.plot(a)

ax.set_xlabel("Temps (s)")
ax.set_ylabel("Amplitude")
# Out:
# Start recording
# End recording
# Text(0, 0.5, 'Amplitude')

# %% [markdown]
# # Calcul de l'amplitude

# %%
amplitude = (np.max(a) - np.min(a))/2
print(amplitude)
# Out:
# 0.023651123046875

# %% [markdown]
# # Calcul de la fréquence

# %%
motifs = 0
for i in range(len(a[:-1])):
    if a[i] < 0 and a[i + 1] > 0:
        motifs +=1
        
periode = d/motifs
frequence = 1/periode
print("frequence :", frequence, "amplitude :", amplitude)
# Out:
# frequence : 19843.6 amplitude : 0.023651123046875

# %% [markdown]
# # Tests (changements de fréquence)

# %%
Fréquence de 20 / amplitude de 0.127
Fréquence de 200 / amplitude de 0.0058
Fréquence de 500 / amplitude de 0.0066
Fréquence de 1000 / amplitude de 0.0078
Fréquence de 2000 / amplitude de 0.01025
Fréquence de 5000 / amplitude de 0.03315
Fréquence de 10000 / amplitude de 0.02598
Fréquence de 15000 / amplitude de 0.03015
Fréquence de 20000 / amplitude de 0.02365
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_5428/882296213.py", line 1
#     Fréquence de 20 / amplitude de 0.127
#               ^
# SyntaxError: invalid syntax
